# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
X = stats.binom(50, 0.7)
_X = X.rvs(size=5000)

# %%
minimum = min(_X)
maximum = max(_X)
print(minimum, maximum)
# Out:
# 24 45

# %%
Q1 = np.quantile(_X, 0.25)
Q2 = np.quantile(_X, 0.5)
Q3 = np.quantile(_X, 0.75)
print(Q1, Q2, Q3)
# Out:
# 33.0 35.0 37.0

# %%
plt.boxplot(_X)
plt.show()

# %%
plt.hist(_X)
plt.title('Do thi tan so')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
plt.hist(_X, density=True)
plt.title('Do thi tan suat')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
_x = np.arange(-5,5,0.01)
pmf=X.pmf(_x)
PDF = plt.plot(_x, pdf)
plt.xlabel('x')
plt.ylabel('f_T(t)')
plt.show()

# %%
plt.hist(pmf)
plt.show()
