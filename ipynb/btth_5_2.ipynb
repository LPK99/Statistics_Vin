# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
mean=[165, 55]
cov=[[100, 0.4],[0.4 ,36]]

# %%
x, y = np.random.multivariate_normal(mean, cov, 5000).T

# %%
print(min(x),
min(y),
max(x),
max(y))
# Out:
# 77.99050634107499

# %%
Q1 = np.quantile(x, 0.25)
Q2 = np.quantile(x, 0.5)
Q3 = np.quantile(x, 0.75)
print(Q1, Q2, Q3)
Q1 = np.quantile(y, 0.25)
Q2 = np.quantile(y, 0.5)
Q3 = np.quantile(y, 0.75)
print(Q1, Q2, Q3)
# Out:
# 158.61668807493066 164.98709604753077 171.6854670896792
# 50.83748082330736 54.78352658207892 59.105418081493966

# %%
datanew=[x, y]
plt.boxplot(datanew)
plt.show()
