# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import numpy as np
iris = datasets.load_iris()
x = iris.data
y = iris.target
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)
# Out:
# 150
# 50

# %%
val, cnt = np.unique(y, return_counts=True)
pmf = cnt / len(y)
val_train, cnt_train = np.unique(y_train, return_counts=True)
pmf_train = cnt_train / len(y_train)
val_test, cnt_test = np.unique(y_test, return_counts=True)
pmf_test = cnt_test / len(y_test)
print(np.column_stack((val, pmf)))
print(np.column_stack((val_train, pmf_train)))
print(np.column_stack((val_test, pmf_test)))
# Out:
# [[0.         0.33333333]
#  [1.         0.33333333]
#  [2.         0.33333333]]
# [[0.         0.33333333]
#  [1.         0.31428571]
#  [2.         0.35238095]]
# [[0.         0.33333333]
#  [1.         0.37777778]
#  [2.         0.28888889]]
# [0.33333333 0.33333333 0.33333333]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
PMF = sns.barplot(val, pmf)
PMF.set(xlabel = 'X', ylabel =  'P_x(x)')
plt.show()
# Out:
# C:\Users\trung\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
PMF = sns.barplot(val_train, pmf_train)
PMF.set(xlabel = 'X_train', ylabel =  'P_x(x)')
plt.show()
# Out:
# C:\Users\trung\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
PMF = sns.barplot(val_test, pmf_test)
PMF.set(xlabel = 'X_test', ylabel =  'P_x(x)')
plt.show()
# Out:
# C:\Users\trung\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
cdf = np.cumsum(pmf)
CDF = sns.barplot(y, cdf)
CDF.set(xlabel = 'y', ylabel = 'F_x(x)')
plt.show()
# Out:
# C:\Users\trung\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9052/2524947508.py in <module>
#       1 cdf = np.cumsum(pmf)
# ----> 2 CDF = sns.barplot(y_test, cdf)
#       3 CDF.set(xlabel = 'y', ylabel = 'F_x(x)')
#       4 plt.show()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3177 ):
#    3178
# -> 3179     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3180                           estimator, ci, n_boot, units, seed,
#    3181                           orient, color, palette, saturation,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     204
#     205                 # Group the numeric data
# --> 206                 plot_data, value_label = self._group_longform(vals, groups,
#     207                                                               group_names)
#     208
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py in _group_longform(self, vals, grouper, order)
#     251
#     252         # Group the val data
# --> 253         grouped_vals = vals.groupby(grouper)
#     254         out_data = []
#     255         for g in order:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1881         # error: Argument "squeeze" to "SeriesGroupBy" has incompatible type
#    1882         # "Union[bool, NoDefault]"; expected "bool"
# -> 1883         return SeriesGroupBy(
#    1884             obj=self,
#    1885             keys=by,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     886             from pandas.core.groupby.grouper import get_grouper
#     887
# --> 888             grouper, exclusions, obj = get_grouper(
#     889                 obj,
#     890                 keys,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     875         # allow us to passing the actual Grouping as the gpr
#     876         ping = (
# --> 877             Grouping(
#     878                 group_axis,
#     879                 gpr,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\grouper.py in __init__(self, index, grouper, obj, level, sort, observed, in_axis, dropna)
#     467         self.level = level
#     468         self._orig_grouper = grouper
# --> 469         self.grouping_vector = _convert_grouper(index, grouper)
#     470         self._all_grouper = None
#     471         self._index = index
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\grouper.py in _convert_grouper(axis, grouper)
#     919     elif isinstance(grouper, (list, tuple, Series, Index, np.ndarray)):
#     920         if len(grouper) != len(axis):
# --> 921             raise ValueError("Grouper and axis must be same length")
#     922
#     923         if isinstance(grouper, (list, tuple)):
#
# ValueError: Grouper and axis must be same length
