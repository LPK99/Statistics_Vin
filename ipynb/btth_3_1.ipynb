# %%
import seaborn as sns
from scipy import stats
import numpy as np
X = stats.poisson.rvs(30, size=5000)
print(X)
print(X.mean())
print(X.std())
print(X.var())
_x = (X == 35).sum()
pmf = _x/len(X)
print(pmf)
val, cnt = np.unique(X, return_counts=True)
_pmf = cnt / len(X)
cdf = np.cumsum(_pmf)
cdf[15]
# Out:
# [36 42 28 ... 30 31 28]
# 29.9664
# 5.518919372485885
# 30.45847104
# 0.0466
# 0.34240000000000004

# %%
help(stats.poisson)
# Out:
# Help on poisson_gen in module scipy.stats._discrete_distns:
#
# <scipy.stats._discrete_distns.poisson_gen object>
#     A Poisson discrete random variable.
#
#     As an instance of the `rv_discrete` class, `poisson` object inherits from it
#     a collection of generic methods (see below for the full list),
#     and completes them with details specific for this particular distribution.
#
#     Methods
#     -------
#     rvs(mu, loc=0, size=1, random_state=None)
#         Random variates.
#     pmf(k, mu, loc=0)
#         Probability mass function.
#     logpmf(k, mu, loc=0)
#         Log of the probability mass function.
#     cdf(k, mu, loc=0)
#         Cumulative distribution function.
#     logcdf(k, mu, loc=0)
#         Log of the cumulative distribution function.
#     sf(k, mu, loc=0)
#         Survival function  (also defined as ``1 - cdf``, but `sf` is sometimes more accurate).
#     logsf(k, mu, loc=0)
#         Log of the survival function.
#     ppf(q, mu, loc=0)
# ...

# %%
X
# Out:
# array([36, 42, 28, ..., 30, 31, 28])

# %%
Y = stats.poisson(30)

# %%
Y.mean()
# Out:
# 30.0

# %%
Y.var()
# Out:
# 30.0

# %%
Y.pmf(35)
# Out:
# 0.045308200086552224

# %%
Y.cdf(15)
# Out:
# 0.0019474797778723041

# %%
import seaborn as sns
import matplotlib.pyplot as plt
poisson = np.arange(0, 100)
_pmf = Y.pmf(poisson)
PMF =sns.barplot(poisson, _pmf)
PMF.set(xlabel='x_', ylabel='y_')
plt.show()
# Out:
# C:\Users\trung\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Out:
# array([9.35762297e-14, 2.80728689e-12, 4.21093034e-11, 4.21093034e-10,
#        3.15819775e-09, 1.89491865e-08, 9.47459326e-08, 4.06053997e-07,
#        1.52270249e-06, 5.07567496e-06, 1.52270249e-05, 4.15282497e-05,
#        1.03820624e-04, 2.39586056e-04, 5.13398691e-04, 1.02679738e-03,
#        1.92524509e-03, 3.39749134e-03, 5.66248556e-03, 8.94076668e-03])
