# %%
from scipy.stats import t
import numpy as np
import matplotlib.pyplot as plt
dof = 15
X = t(dof)
_X = X.rvs(size=1000)

# %%
X.mean()
# Out:
# 0.0

# %%
X.var()
# Out:
# 1.1538461538461537

# %%
X.std()
# Out:
# 1.0741723110591492

# %%
X.ppf(0.9)
# Out:
# 1.3406056078504547

# %%
X.ppf(0.95)
# Out:
# 1.7530503556925547

# %%
X.ppf(0.95)
# Out:
# 1.7530503556925547

# %%
_x = np.arange(-5,5,0.01)
pdf=X.pdf(_x)
PDF = plt.plot(_x, pdf)
plt.xlabel('x')
plt.ylabel('f_T(t)')
plt.show()

# %%
cdf = X.cdf(_x)
CDF = plt.plot(_x, cdf)
plt.xlabel('x')
plt.ylabel('F_T(t)')
plt.show()
